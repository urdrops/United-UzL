# %% [markdown]
# <a href="https://colab.research.google.com/github/urdrops/United-UzL/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import dependencies
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np

# %%
# Set hyperparameters/arguments
batch_size = 64
epochs = 100
latent_dim = 256
num_samples = 10000
data_path = 'Xorez-Adabiy/rus.txt'

# %%
# Read input texts and output texts from file into lists
input_texts = []
target_texts = []
input_chars = set()
target_chars = set() # Set faster than list to search through

with open(data_path, 'r', encoding='utf-8') as f:
    count = 0
    for line in f:
        if count == num_samples:
            break
        # Separate input and target pairs and add a start sequence character to target text
        input_text, target_text = line.split('\t')
        target_text = '\t' + target_text
        input_texts.append(input_text)
        target_texts.append(target_text)
        # Create set containing unique input characters
        for char in input_text:
            if char not in input_chars:
                input_chars.add(char)
        # Create set containing unique target characters
        for char in target_text:
            if char not in target_chars:
                target_chars.add(char)
        count += 1

# %%
# Convert the set of input characters and target characters to lists and sort them
input_chars = sorted(list(input_chars))
target_chars = sorted(list(target_chars))

# Information on variables
num_encoder_tokens = len(input_chars)
num_decoder_tokens = len(target_chars)
max_encoder_seq_length = len(max(input_texts, key=len))
max_decoder_seq_length = len(max(target_texts, key=len))

# Print information
print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 110
# Number of unique input tokens: 44
# Number of unique output tokens: 61
# Max sequence length for inputs: 8
# Max sequence length for outputs: 28

# %%
# Create dictionaries that maps characters to indices and vice versa
input_token_index = dict((char, i) for i, char in enumerate(input_chars))
target_token_index = dict((char, i) for i, char in enumerate(target_chars))

reverse_input_token_index = dict((i, c) for i, c in enumerate(input_chars))
reverse_target_token_index = dict((i, c) for i, c in enumerate(target_chars))

# %%
# Use text to create arrays for input and output (target) sequences

# Initialize input and target data
encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

# Iterate through examples
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    # Iterate through input sequence
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    # Iterate through output sequence
    for t, char in enumerate(target_text):
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# Print variable shapes
print('Encoder input shape:', encoder_input_data.shape)
print('Decoder input shape:', decoder_input_data.shape)
print('Decoder target shape:', decoder_target_data.shape)
# Out:
# Encoder input shape: (110, 8, 44)
# Decoder input shape: (110, 28, 61)
# Decoder target shape: (110, 28, 61)

# %%
# Encoder
encoder_inputs = Input(shape=(None, num_encoder_tokens))
_, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_inputs)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None, num_decoder_tokens))
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy' , metrics = ['accuracy'])

# Fit model
model.fit(x=[encoder_input_data, decoder_input_data], 
          y=decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.1
          )
# Out:
# Epoch 1/100
# 2/2 [==============================] - 6s 1s/step - loss: 0.0411 - accuracy: 0.2937 - val_loss: 0.0430 - val_accuracy: 0.1266
# Epoch 2/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0331 - accuracy: 0.3009 - val_loss: 0.0775 - val_accuracy: 0.1169
# Epoch 3/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0497 - accuracy: 0.2897 - val_loss: 0.1039 - val_accuracy: 0.1006
# Epoch 4/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0523 - accuracy: 0.2810 - val_loss: 0.0903 - val_accuracy: 0.0974
# Epoch 5/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0440 - accuracy: 0.2713 - val_loss: 0.0635 - val_accuracy: 0.0974
# Epoch 6/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0381 - accuracy: 0.2619 - val_loss: 0.0489 - val_accuracy: 0.1266
# Epoch 7/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0309 - accuracy: 0.2540 - val_loss: 0.0409 - val_accuracy: 0.1331
# Epoch 8/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0276 - accuracy: 0.2532 - val_loss: 0.0395 - val_accuracy: 0.1331
# Epoch 9/100
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0255 - accuracy: 0.2500 - val_loss: 0.0399 - val_accuracy: 0.1396
# Epoch 10/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0246 - accuracy: 0.2489 - val_loss: 0.0367 - val_accuracy: 0.1591
# Epoch 11/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0235 - accuracy: 0.2507 - val_loss: 0.0359 - val_accuracy: 0.1623
# Epoch 12/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0227 - accuracy: 0.2543 - val_loss: 0.0364 - val_accuracy: 0.1623
# Epoch 13/100
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0221 - accuracy: 0.2615 - val_loss: 0.0342 - val_accuracy: 0.1623
# Epoch 14/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0212 - accuracy: 0.2637 - val_loss: 0.0342 - val_accuracy: 0.1623
# Epoch 15/100
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0204 - accuracy: 0.2655 - val_loss: 0.0362 - val_accuracy: 0.1623
# Epoch 16/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0201 - accuracy: 0.2720 - val_loss: 0.0360 - val_accuracy: 0.1591
# Epoch 17/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0197 - accuracy: 0.2716 - val_loss: 0.0366 - val_accuracy: 0.1558
# Epoch 18/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0193 - accuracy: 0.2727 - val_loss: 0.0379 - val_accuracy: 0.1558
# Epoch 19/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0190 - accuracy: 0.2738 - val_loss: 0.0368 - val_accuracy: 0.1591
# Epoch 20/100
# 2/2 [==============================] - 0s 213ms/step - loss: 0.0187 - accuracy: 0.2763 - val_loss: 0.0376 - val_accuracy: 0.1623
# Epoch 21/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0184 - accuracy: 0.2785 - val_loss: 0.0392 - val_accuracy: 0.1688
# Epoch 22/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0182 - accuracy: 0.2843 - val_loss: 0.0384 - val_accuracy: 0.1721
# Epoch 23/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0179 - accuracy: 0.2890 - val_loss: 0.0388 - val_accuracy: 0.1623
# Epoch 24/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0176 - accuracy: 0.2922 - val_loss: 0.0391 - val_accuracy: 0.1623
# Epoch 25/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0174 - accuracy: 0.2937 - val_loss: 0.0398 - val_accuracy: 0.1591
# Epoch 26/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0172 - accuracy: 0.2955 - val_loss: 0.0413 - val_accuracy: 0.1591
# Epoch 27/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0170 - accuracy: 0.2962 - val_loss: 0.0423 - val_accuracy: 0.1591
# Epoch 28/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0168 - accuracy: 0.2969 - val_loss: 0.0429 - val_accuracy: 0.1591
# Epoch 29/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0166 - accuracy: 0.2980 - val_loss: 0.0438 - val_accuracy: 0.1591
# Epoch 30/100
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0164 - accuracy: 0.2994 - val_loss: 0.0448 - val_accuracy: 0.1591
# Epoch 31/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0163 - accuracy: 0.3023 - val_loss: 0.0467 - val_accuracy: 0.1591
# Epoch 32/100
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0161 - accuracy: 0.3045 - val_loss: 0.0464 - val_accuracy: 0.1591
# Epoch 33/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0159 - accuracy: 0.3063 - val_loss: 0.0469 - val_accuracy: 0.1591
# Epoch 34/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0158 - accuracy: 0.3059 - val_loss: 0.0472 - val_accuracy: 0.1656
# Epoch 35/100
# 2/2 [==============================] - 0s 188ms/step - loss: 0.0156 - accuracy: 0.3077 - val_loss: 0.0469 - val_accuracy: 0.1656
# Epoch 36/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0155 - accuracy: 0.3077 - val_loss: 0.0495 - val_accuracy: 0.1656
# Epoch 37/100
# 2/2 [==============================] - 0s 178ms/step - loss: 0.0153 - accuracy: 0.3110 - val_loss: 0.0485 - val_accuracy: 0.1623
# Epoch 38/100
# 2/2 [==============================] - 0s 178ms/step - loss: 0.0152 - accuracy: 0.3135 - val_loss: 0.0499 - val_accuracy: 0.1591
# Epoch 39/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0150 - accuracy: 0.3139 - val_loss: 0.0486 - val_accuracy: 0.1591
# Epoch 40/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0149 - accuracy: 0.3149 - val_loss: 0.0495 - val_accuracy: 0.1591
# Epoch 41/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0147 - accuracy: 0.3175 - val_loss: 0.0500 - val_accuracy: 0.1461
# Epoch 42/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0146 - accuracy: 0.3178 - val_loss: 0.0502 - val_accuracy: 0.1494
# Epoch 43/100
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0144 - accuracy: 0.3218 - val_loss: 0.0510 - val_accuracy: 0.1494
# Epoch 44/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0143 - accuracy: 0.3236 - val_loss: 0.0500 - val_accuracy: 0.1494
# Epoch 45/100
# 2/2 [==============================] - 0s 197ms/step - loss: 0.0142 - accuracy: 0.3247 - val_loss: 0.0511 - val_accuracy: 0.1494
# Epoch 46/100
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0141 - accuracy: 0.3261 - val_loss: 0.0497 - val_accuracy: 0.1494
# Epoch 47/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0139 - accuracy: 0.3294 - val_loss: 0.0512 - val_accuracy: 0.1494
# Epoch 48/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0138 - accuracy: 0.3319 - val_loss: 0.0497 - val_accuracy: 0.1461
# Epoch 49/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0137 - accuracy: 0.3344 - val_loss: 0.0516 - val_accuracy: 0.1461
# Epoch 50/100
# 2/2 [==============================] - 0s 193ms/step - loss: 0.0135 - accuracy: 0.3359 - val_loss: 0.0499 - val_accuracy: 0.1429
# Epoch 51/100
# 2/2 [==============================] - 0s 189ms/step - loss: 0.0134 - accuracy: 0.3369 - val_loss: 0.0522 - val_accuracy: 0.1429
# Epoch 52/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0133 - accuracy: 0.3395 - val_loss: 0.0505 - val_accuracy: 0.1331
# Epoch 53/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0131 - accuracy: 0.3405 - val_loss: 0.0506 - val_accuracy: 0.1331
# Epoch 54/100
# 2/2 [==============================] - 0s 182ms/step - loss: 0.0130 - accuracy: 0.3431 - val_loss: 0.0507 - val_accuracy: 0.1331
# Epoch 55/100
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0129 - accuracy: 0.3460 - val_loss: 0.0510 - val_accuracy: 0.1331
# Epoch 56/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0128 - accuracy: 0.3463 - val_loss: 0.0510 - val_accuracy: 0.1331
# Epoch 57/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0126 - accuracy: 0.3463 - val_loss: 0.0509 - val_accuracy: 0.1331
# Epoch 58/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0125 - accuracy: 0.3470 - val_loss: 0.0501 - val_accuracy: 0.1331
# Epoch 59/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0124 - accuracy: 0.3488 - val_loss: 0.0500 - val_accuracy: 0.1331
# Epoch 60/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0123 - accuracy: 0.3503 - val_loss: 0.0503 - val_accuracy: 0.1331
# Epoch 61/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0121 - accuracy: 0.3514 - val_loss: 0.0501 - val_accuracy: 0.1331
# Epoch 62/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0120 - accuracy: 0.3517 - val_loss: 0.0506 - val_accuracy: 0.1331
# Epoch 63/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0119 - accuracy: 0.3535 - val_loss: 0.0498 - val_accuracy: 0.1299
# Epoch 64/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0118 - accuracy: 0.3553 - val_loss: 0.0506 - val_accuracy: 0.1299
# Epoch 65/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.0117 - accuracy: 0.3568 - val_loss: 0.0506 - val_accuracy: 0.1266
# Epoch 66/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0116 - accuracy: 0.3586 - val_loss: 0.0505 - val_accuracy: 0.1201
# Epoch 67/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0114 - accuracy: 0.3589 - val_loss: 0.0499 - val_accuracy: 0.1169
# Epoch 68/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0113 - accuracy: 0.3604 - val_loss: 0.0503 - val_accuracy: 0.1169
# Epoch 69/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0112 - accuracy: 0.3626 - val_loss: 0.0498 - val_accuracy: 0.1071
# Epoch 70/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0111 - accuracy: 0.3644 - val_loss: 0.0510 - val_accuracy: 0.1104
# Epoch 71/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0110 - accuracy: 0.3662 - val_loss: 0.0505 - val_accuracy: 0.1104
# Epoch 72/100
# 2/2 [==============================] - 0s 192ms/step - loss: 0.0109 - accuracy: 0.3672 - val_loss: 0.0497 - val_accuracy: 0.0942
# Epoch 73/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0108 - accuracy: 0.3683 - val_loss: 0.0515 - val_accuracy: 0.0942
# Epoch 74/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0107 - accuracy: 0.3690 - val_loss: 0.0510 - val_accuracy: 0.0942
# Epoch 75/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0105 - accuracy: 0.3698 - val_loss: 0.0507 - val_accuracy: 0.0942
# Epoch 76/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0104 - accuracy: 0.3712 - val_loss: 0.0507 - val_accuracy: 0.0942
# Epoch 77/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0103 - accuracy: 0.3730 - val_loss: 0.0503 - val_accuracy: 0.0942
# Epoch 78/100
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0102 - accuracy: 0.3734 - val_loss: 0.0508 - val_accuracy: 0.0942
# Epoch 79/100
# 2/2 [==============================] - 0s 198ms/step - loss: 0.0101 - accuracy: 0.3755 - val_loss: 0.0503 - val_accuracy: 0.0942
# Epoch 80/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0100 - accuracy: 0.3781 - val_loss: 0.0501 - val_accuracy: 0.0942
# Epoch 81/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0099 - accuracy: 0.3802 - val_loss: 0.0519 - val_accuracy: 0.0909
# Epoch 82/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0098 - accuracy: 0.3813 - val_loss: 0.0496 - val_accuracy: 0.0909
# Epoch 83/100
# 2/2 [==============================] - 0s 218ms/step - loss: 0.0097 - accuracy: 0.3810 - val_loss: 0.0502 - val_accuracy: 0.0909
# Epoch 84/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0096 - accuracy: 0.3817 - val_loss: 0.0514 - val_accuracy: 0.0877
# Epoch 85/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0095 - accuracy: 0.3835 - val_loss: 0.0496 - val_accuracy: 0.0877
# Epoch 86/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0094 - accuracy: 0.3856 - val_loss: 0.0526 - val_accuracy: 0.0877
# Epoch 87/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0094 - accuracy: 0.3882 - val_loss: 0.0495 - val_accuracy: 0.0812
# Epoch 88/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.0093 - accuracy: 0.3885 - val_loss: 0.0512 - val_accuracy: 0.0844
# Epoch 89/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0091 - accuracy: 0.3900 - val_loss: 0.0534 - val_accuracy: 0.0844
# Epoch 90/100
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0091 - accuracy: 0.3900 - val_loss: 0.0486 - val_accuracy: 0.0844
# Epoch 91/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0090 - accuracy: 0.3929 - val_loss: 0.0510 - val_accuracy: 0.0844
# Epoch 92/100
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0089 - accuracy: 0.3936 - val_loss: 0.0502 - val_accuracy: 0.0844
# Epoch 93/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0089 - accuracy: 0.3939 - val_loss: 0.0482 - val_accuracy: 0.0844
# Epoch 94/100
# 2/2 [==============================] - 0s 185ms/step - loss: 0.0088 - accuracy: 0.3950 - val_loss: 0.0508 - val_accuracy: 0.0844
# Epoch 95/100
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0088 - accuracy: 0.3972 - val_loss: 0.0475 - val_accuracy: 0.0779
# Epoch 96/100
# 2/2 [==============================] - 0s 181ms/step - loss: 0.0087 - accuracy: 0.3975 - val_loss: 0.0508 - val_accuracy: 0.0812
# Epoch 97/100
# 2/2 [==============================] - 0s 179ms/step - loss: 0.0087 - accuracy: 0.3979 - val_loss: 0.0468 - val_accuracy: 0.0779
# Epoch 98/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.0087 - accuracy: 0.4004 - val_loss: 0.0486 - val_accuracy: 0.0779
# Epoch 99/100
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0086 - accuracy: 0.3997 - val_loss: 0.0559 - val_accuracy: 0.0844
# Epoch 100/100
# 2/2 [==============================] - 0s 177ms/step - loss: 0.0084 - accuracy: 0.4015 - val_loss: 0.0479 - val_accuracy: 0.0779

# %%
# Save model
model.save('s2s.h5')

# %%
# Encoder model
encoder_model = Model(encoder_inputs, encoder_states) 

# Decoder states inputs
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

# Decoder outputs
decoder_outputs, state_h, state_c = decoder_lstm(decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

# Decoder model
decoder_model = Model([decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states)

# %%
"""
This function takes the previously calculated state vectors (hidden state & cell state) and output token
to predict the next state vectors and output token. It does this iteratively until it predicts the "end
sequence" token (or reaches a certain amount of iterations) to at which point it stops. Each predicted 
token will be converted to its character representation and added to a string which will hopefully be 
the correct translation by the end of the loop.
"""

def decode_sequence(input_seq):
    # Initialize hidden and cell state to be the hidden and cell state from the encoder
    states_value = encoder_model.predict(input_seq) # [hidden state, cell state]

    # Initialize decoder input to the "start character"
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Initialize an empty string to hold the translation
    decoded_sentence = ''
    
    while True:
        # Predict the next output token and states
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Add the predicted tokens character representation to the string
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_token_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit loop if the "end sequence" character is predicted or if the decoded sentence reaches 
        # a max length
        if (sampled_char == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            break

        # Update the decoder input with the new predicted character
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update the states
        states_value = [h, c]

    return decoded_sentence

# %%
# Prints predicted translations
for seq_index in range(10):
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    #print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 397ms/step
# 1/1 [==============================] - 1s 910ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# Input sentence: Go.
# Decoded sentence: Va
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 20ms/step
# Input sentence: Run!
# Decoded sentence: Corree
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# Input sentence: Run!
# Decoded sentence: Corree
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# Input sentence: Wow!
# Decoded sentence: Coarsss
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# Input sentence: Fire!
# Decoded sentence: Aeeteee
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# Input sentence: Help!
# Decoded sentence: Aeraii
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# Input sentence: Jump.
# Decoded sentence: Soreee
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# Input sentence: Stop!
# Decoded sentence: Atteee
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# Input sentence: Stop!
# Decoded sentence: Atteee
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# Input sentence: Stop!
# Decoded sentence: Atteee

# %%
decoded_sentence
# Out:
# 'Ça ssff\n'
